# %% [markdown]
# <a href="https://colab.research.google.com/github/abyasingh/MakeItTalk/blob/main/Improvement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 360, done.
# remote: Total 360 (delta 0), reused 0 (delta 0), pack-reused 360
# Receiving objects: 100% (360/360), 522.32 KiB | 11.61 MiB/s, done.
# Resolving deltas: 100% (198/198), done.

# %%
# !ls /content/gdrive/MyDrive/Wav2Lip
# Out:
# test.mp4  test.wav  wav2lip.pth

# %%
# !cp -ri "/content/gdrive/MyDrive/Wav2Lip/wav2lip.pth" /content/Wav2Lip/checkpoints/

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# Found existing installation: tensorflow 2.12.0
# Uninstalling tensorflow-2.12.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.9/dist-packages/tensorflow-2.12.0.dist-info/*
#     /usr/local/lib/python3.9/dist-packages/tensorflow/*
# Proceed (Y/n)? y
# y
#   Successfully uninstalled tensorflow-2.12.0
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 109.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.1.0.25 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72)
# ERROR: No matching distribution found for opencv-python==4.1.0.25

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2023-04-13 18:42:23--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M  18.9MB/s    in 5.3s
#
# 2023-04-13 18:42:29 (16.0 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %%
# !cp "/content/gdrive/My Drive/Wav2Lip/test.mp4" "/content/gdrive/My Drive/Wav2Lip/test.wav" sample_data/
# !ls sample_data/

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/test.mp4" --audio "../sample_data/test.wav"
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 185
# (80, 391)
# Length of mel chunks: 119
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/8 [00:00<?, ?it/s]
#  12% 1/8 [00:13<01:36, 13.74s/it]
#  25% 2/8 [00:14<00:37,  6.28s/it]
#  38% 3/8 [00:15<00:19,  3.90s/it]
#  50% 4/8 [00:16<00:10,  2.74s/it]
#  62% 5/8 [00:17<00:06,  2.07s/it]
#  75% 6/8 [00:18<00:03,  1.68s/it]
#  88% 7/8 [00:19<00:01,  1.43s/it]
# 100% 8/8 [00:25<00:00,  3.13s/it]
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Model loaded
# 100% 1/1 [00:37<00:00, 37.31s/it]
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/Wav2Lip/results/result_voice.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""
<video width="50%" height="50%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="50%" height="50%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from google.colab import files
files.download('/content/Wav2Lip/results/result_voice.mp4')
